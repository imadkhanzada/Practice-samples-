# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
import os

# %%
os.chdir('D:\Data Science\Datasets')

# %%
data= pd.read_csv('AirPassengers - Govindaraj V.csv')

# %%
data.head(8)
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121
# 5  1949-06          135
# 6  1949-07          148
# 7  1949-08          148

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    object
#  1   #Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
data.describe().T
# Out:
#              count        mean         std    min    25%    50%    75%    max
# #Passengers  144.0  280.298611  119.966317  104.0  180.0  265.5  360.5  622.0

# %% [markdown]
# Reading as date format

# %%
dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m')
data = pd.read_csv('AirPassengers - Govindaraj V.csv', parse_dates=['Month'],
                   index_col='Month',date_parser =dateparse)
print (data.head())
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121
# <ipython-input-10-54993683e307>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m')

# %%
#Checking data type of Index 
data.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq=None)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 144 entries, 1949-01-01 to 1960-12-01
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   #Passengers  144 non-null    int64
# dtypes: int64(1)
# memory usage: 2.2 KB

# %%
#convert to time series 
ts=data['#Passengers']
ts.head(6)
# Out:
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
# 1949-06-01    135
# Name: #Passengers, dtype: int64

# %%
ts['1949-04-01']
# Out:
# 129

# %%
#we can do slicing also 
ts['1949-01-01': '1949-05-01']
# Out:
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
# Name: #Passengers, dtype: int64

# %% [markdown]
# # Checking for stationarity
# Plot the time-series

# %%
plt.figure(figsize=(10,5))
plt.plot(ts,color='blue')

# %% [markdown]
# **Function for testing stationarity**

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(window=12).mean()
    rolstd = timeseries.rolling(window=12).std()

    #Plot rolling statistics:
    plt.figure(figsize=(12,5))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='green', label='Rolling Mean')
    std = plt.plot(rolstd, color='red', label = 'Rolling Std')
    plt.legend(loc='upper left')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(ts)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   0.815369
# p-value                          0.991880
# #Lags Used                      13.000000
# Number of Observations Used    130.000000
# Critical Value (1%)             -3.481682
# Critical Value (5%)             -2.884042
# Critical Value (10%)            -2.578770
# dtype: float64

# %% [markdown]
# # Making TS Stationary
# **Estimating & Eliminating Trend
# so we are taking the log here **

# %%
ts_log=np.log(ts)
plt.figure(figsize=(8,5))
plt.plot(ts_log,color='blue')

# %% [markdown]
# # Now we will do Smoothing
# i.e Moving Average

# %%
moving_avg=ts_log.rolling(window=12).mean()
plt.plot(ts_log)
plt.plot(moving_avg, color='green')

# %%
ts_log_moving_avg_diff = ts_log - moving_avg
ts_log_moving_avg_diff.head(12)
# Out:
# Month
# 1949-01-01         NaN
# 1949-02-01         NaN
# 1949-03-01         NaN
# 1949-04-01         NaN
# 1949-05-01         NaN
# 1949-06-01         NaN
# 1949-07-01         NaN
# 1949-08-01         NaN
# 1949-09-01         NaN
# 1949-10-01         NaN
# 1949-11-01         NaN
# 1949-12-01   -0.065494
# Name: #Passengers, dtype: float64

# %%
ts_log_moving_avg_diff.dropna(inplace=True)
ts_log_moving_avg_diff.head(7)
# Out:
# Month
# 1949-12-01   -0.065494
# 1950-01-01   -0.093449
# 1950-02-01   -0.007566
# 1950-03-01    0.099416
# 1950-04-01    0.052142
# 1950-05-01   -0.027529
# 1950-06-01    0.139881
# Name: #Passengers, dtype: float64

# %%
test_stationarity(ts_log_moving_avg_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -3.162908
# p-value                          0.022235
# #Lags Used                      13.000000
# Number of Observations Used    119.000000
# Critical Value (1%)             -3.486535
# Critical Value (5%)             -2.886151
# Critical Value (10%)            -2.579896
# dtype: float64

# %% [markdown]
# **Exponentially Weighted Moving Average**

# %%
expwighted_avg = ts_log.ewm(halflife=12).mean()
plt.plot(ts_log)
plt.plot(expwighted_avg, color='red')

# %%
expwighted_avg
# Out:
# Month
# 1949-01-01    4.718499
# 1949-02-01    4.745345
# 1949-03-01    4.793835
# 1949-04-01    4.811785
# 1949-05-01    4.808206
#                 ...
# 1960-08-01    6.046445
# 1960-09-01    6.056778
# 1960-10-01    6.061079
# 1960-11-01    6.055750
# 1960-12-01    6.056461
# Name: #Passengers, Length: 144, dtype: float64

# %%
ts
# Out:
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
#              ...
# 1960-08-01    606
# 1960-09-01    508
# 1960-10-01    461
# 1960-11-01    390
# 1960-12-01    432
# Name: #Passengers, Length: 144, dtype: int64

# %%
ts_log
# Out:
# Month
# 1949-01-01    4.718499
# 1949-02-01    4.770685
# 1949-03-01    4.882802
# 1949-04-01    4.859812
# 1949-05-01    4.795791
#                 ...
# 1960-08-01    6.406880
# 1960-09-01    6.230481
# 1960-10-01    6.133398
# 1960-11-01    5.966147
# 1960-12-01    6.068426
# Name: #Passengers, Length: 144, dtype: float64

# %%
ts_log_ewma_diff=ts_log -ts_log_moving_avg_diff
ts_log_ewma_diff.head()
# Out:
# Month
# 1949-01-01   NaN
# 1949-02-01   NaN
# 1949-03-01   NaN
# 1949-04-01   NaN
# 1949-05-01   NaN
# Name: #Passengers, dtype: float64

# %%
ts_log_ewma_diff.dropna(inplace=True)
ts_log_ewma_diff.head()
# Out:
# Month
# 1949-12-01    4.836178
# 1950-01-01    4.838381
# 1950-02-01    4.843848
# 1950-03-01    4.849344
# 1950-04-01    4.853133
# Name: #Passengers, dtype: float64

# %%
ts_log_ewma_diff = ts_log - expwighted_avg
test_stationarity(ts_log_ewma_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -3.601262
# p-value                          0.005737
# #Lags Used                      13.000000
# Number of Observations Used    130.000000
# Critical Value (1%)             -3.481682
# Critical Value (5%)             -2.884042
# Critical Value (10%)            -2.578770
# dtype: float64

# %% [markdown]
# # Eliminating Trend and Seasonality
# Differencing:

# %%
plt.figure(figsize=(8,4))
ts_log_diff = ts_log - ts_log.shift()
plt.plot(ts_log_diff)

# %%
ts_log.head(3)
# Out:
# Month
# 1949-01-01    4.718499
# 1949-02-01    4.770685
# 1949-03-01    4.882802
# Name: #Passengers, dtype: float64

# %%
ts_log.shift() ##here first value is shifted
# Out:
# Month
# 1949-01-01         NaN
# 1949-02-01    4.718499
# 1949-03-01    4.770685
# 1949-04-01    4.882802
# 1949-05-01    4.859812
#                 ...
# 1960-08-01    6.432940
# 1960-09-01    6.406880
# 1960-10-01    6.230481
# 1960-11-01    6.133398
# 1960-12-01    5.966147
# Name: #Passengers, Length: 144, dtype: float64

# %%
plt.figure(figsize=(10,5))
ts_log_diff.dropna(inplace=True)#dropping Null value 
test_stationarity(ts_log_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.717131
# p-value                          0.071121
# #Lags Used                      14.000000
# Number of Observations Used    128.000000
# Critical Value (1%)             -3.482501
# Critical Value (5%)             -2.884398
# Critical Value (10%)            -2.578960
# dtype: float64

# %% [markdown]
# # Final Forecasting
# **ARIMA Model**

# %%
from  statsmodels.tsa.arima_model import ARIMA

# %%
##---------AR Model----------##
model = ARIMA(ts_log, order=(2, 1, 0))  
results_MA = model.fit(disp=-1)  
plt.figure(figsize=(12,5))
plt.plot(ts_log_diff)
plt.plot(results_MA.fittedvalues, color='green')
plt.title('RSS: %.4f'% sum((results_MA.fittedvalues-ts_log_diff)**2))#Sum of squared values
# Out:
# C:\Users\imad\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\imad\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# Text(0.5, 1.0, 'RSS: 1.5023')

# %%
##-----------MA Model---------##
model = ARIMA(ts_log, order=(0, 1, 2))  
results_MA = model.fit(disp=-1)  
plt.figure(figsize=(12,5))
plt.plot(ts_log_diff)
plt.plot(results_MA.fittedvalues, color='black')
plt.title('RSS: %.4f'% sum((results_MA.fittedvalues-ts_log_diff)**2))#Sum of squared values
# Out:
# C:\Users\imad\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\imad\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# Text(0.5, 1.0, 'RSS: 1.4721')

# %% [markdown]
# # **ARIMA Model**

# %%
model = ARIMA(ts_log, order=(2, 1, 2))  ## change the order 
results_ARIMA = model.fit(disp=-1)  
plt.figure(figsize=(12,5))
plt.plot(ts_log_diff)
plt.plot(results_MA.fittedvalues, color='indigo')
plt.title('RSS: %.4f'% sum((results_ARIMA.fittedvalues-ts_log_diff)**2))#Sum of squared values
# Out:
# C:\Users\imad\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\imad\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:159: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# Text(0.5, 1.0, 'RSS: 1.0292')

# %%
predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)
print (predictions_ARIMA_diff.head())
# Out:
# Month
# 1949-02-01    0.009580
# 1949-03-01    0.017491
# 1949-04-01    0.027670
# 1949-05-01   -0.004521
# 1949-06-01   -0.023890
# dtype: float64

# %%
results_ARIMA.plot_predict(1,180)## 12*10 months(historical data ) +5 years(60months )

# %%
results_ARIMA.plot_predict(1,240)
